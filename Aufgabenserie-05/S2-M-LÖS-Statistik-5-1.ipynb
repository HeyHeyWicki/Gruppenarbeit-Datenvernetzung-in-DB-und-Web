# %% [markdown]
# ## Aufgabe 1 - Recherche zum Thema Zeitreihen
# ### a)	Erstelle eine kurze Zusammenfassung
# Eine Zeitreihe ist eine geordnete Folge von Datenpunkten, die in gleichmäßigen zeitlichen Abständen gesammelt werden. Das zentrale Merkmal einer Zeitreihe ist die Zeitabhängigkeit der Daten: Die Beobachtungen hängen oft von ihrem zeitlichen Verlauf ab, und die Analyse dieser zeitlichen Muster ist das Hauptziel der Zeitreihenanalyse.
#
# In der Statistik und Datenanalyse wird eine Zeitreihe verwendet, um Trends, saisonale Effekte oder auch zufällige Schwankungen zu erkennen und um Vorhersagen für zukünftige Zeitpunkte zu treffen.
#
# Beispiel: Finanzmärkte
# Ein typisches Beispiel für eine Zeitreihe sind Aktienkurse. Der tägliche Schlusskurs einer Aktie wird über eine bestimmte Zeitspanne hinweg aufgezeichnet, z. B. über ein Jahr. Die Zeitreihe könnte dann verwendet werden, um Trends (z. B. langfristige Wertsteigerung oder -minderung), saisonale Schwankungen (z. B. Preisspitzen während bestimmter Monate) oder kurzfristige Volatilität zu analysieren. Auf Grundlage dieser Analysen können Vorhersagen über zukünftige Aktienkurse getroffen werden, um Investitionsentscheidungen zu unterstützen.
#
# Zeitreihenanalysen sind in vielen Bereichen nützlich, von der Wirtschaft bis zur Wettervorhersage, und spielen eine wichtige Rolle bei der Planung und Entscheidungsfindung.
# ### b)	Komponenten
# 1. Trend (T):
# Definition: Der Trend beschreibt die langfristige Bewegung der Daten über einen längeren Zeitraum hinweg. Er zeigt, ob die Zeitreihe insgesamt ansteigt, abfällt oder konstant bleibt.
# Charakterisierung: Ein Trend kann linear oder nicht-linear (z. B. exponentiell) sein. Er bildet langfristige strukturelle Veränderungen in der Zeitreihe ab.
# Identifikation: Der Trend kann durch grafische Darstellung der Zeitreihe sichtbar gemacht werden oder durch statistische Verfahren wie gleitende Durchschnitte oder die Anpassung einer Regressionsgeraden.
#
# 2. Saisonale Komponente (S):
# - Definition: Die saisonale Komponente zeigt wiederkehrende Muster oder Schwankungen in der Zeitreihe, die innerhalb eines festen, wiederkehrenden Zeitintervalls auftreten, z. B. monatlich, jährlich oder wöchentlich.
# - Charakterisierung: Saisonale Effekte sind typischerweise mit zyklischen Ereignissen verbunden, wie Jahreszeiten, Feiertagen oder bestimmten Geschäftszyklen.
# - Identifikation: Saisonale Schwankungen lassen sich häufig durch grafische Inspektion erkennen. Statistische Methoden wie die Zerlegung in additive oder multiplikative Komponenten (z. B. klassische Zerlegung, X-12-ARIMA) oder Fourier-Analysen können verwendet werden.
# 3. Zyklische Komponente (C):
# - Definition: Zyklische Schwankungen beschreiben größere, langfristige Wellenbewegungen in der Zeitreihe, die nicht an feste Intervalle gebunden sind (im Gegensatz zur saisonalen Komponente).
# - Charakterisierung: Zyklische Muster treten oft über mehrere Jahre auf und sind mit wirtschaftlichen oder anderen systematischen Einflüssen verbunden, wie z. B. Konjunkturzyklen. Sie haben eine unregelmäßigere Dauer und Amplitude als saisonale Schwankungen.
# - Identifikation: Zyklische Komponenten werden meist mit Hilfe von statistischen Modellen wie der Autoregressiven Integrierten Bewegungsdurchschnittsmodellen (ARIMA) oder durch glättende Verfahren ermittelt.
# 4. Rest- oder Rauschkomponente (E, für "Error" oder "Residuals"):
# - Definition: Der Rest beschreibt die zufälligen, nicht erklärbaren Schwankungen in der Zeitreihe. Diese Komponente fängt alle zufälligen Störungen und unvorhersehbaren Variationen auf, die nicht durch die anderen Komponenten erklärt werden können.
# - Charakterisierung: Diese Komponente ist unregelmäßig und folgt keiner erkennbaren Struktur.
# - Identifikation: Nachdem Trend, Saison und Zyklus aus der Zeitreihe entfernt wurden (Dekompensation), bleibt der Rest übrig. Statistisch analysiert man diese Komponente, um festzustellen, ob sie einem weißen Rauschen (zufällige Schwankungen ohne Struktur) entspricht.
#
# ### c)  Vorgehen beim Zerlegen
# Die Zerlegung einer Zeitreihe in ihre Hauptkomponenten (Trend, Saison, Zyklus, Rest) wird in der Zeitreihenanalyse verwendet, um ein besseres Verständnis für die zugrunde liegenden Muster zu erlangen. Dies hilft dabei, verschiedene Einflüsse auf die Daten zu trennen und zu analysieren. Es gibt verschiedene Ansätze zur Zerlegung, aber das grundlegende Vorgehen folgt oft diesen Schritten:
#
# 1. Bestimmung des Modells:
# Bevor mit der Zerlegung begonnen wird, muss entschieden werden, ob ein additives oder ein multiplikatives Modell besser zur Datenstruktur passt:
#
#     Additives Modell: Geeignet, wenn saisonale Schwankungen unabhängig vom Niveau der Zeitreihe gleichbleibend sind.
#     Multiplikatives Modell: Geeignet, wenn die saisonalen Schwankungen proportional zum Niveau der Zeitreihe variieren.
#     Die Wahl hängt vom visuellen Erscheinungsbild der Daten und einer ersten Analyse ab. Ein einfacher Test ist, ob die Amplitude der saisonalen Schwankungen mit steigenden Werten der Zeitreihe zunimmt.
#
# 2. Schätzung des Trends:
# Der Trend beschreibt die langfristige Bewegung der Zeitreihe. Typische Methoden zur Bestimmung des Trends sind:
#
#     Gleitende Durchschnitte: Ein gleitender Durchschnitt glättet kurzfristige Schwankungen und hebt den langfristigen Trend hervor. Je größer das Fenster des gleitenden Durchschnitts, desto stärker wird geglättet.
#     Regressionsanalyse: Eine Regressionsgerade oder -kurve wird an die Zeitreihen-Daten angepasst, um den Trend zu bestimmen.
#     Beispiel: Bei monatlichen Daten könnte ein gleitender 12-Monats-Durchschnitt angewendet werden, um den Trend über das Jahr hinweg zu glätten.
#
# 3. Bestimmung der saisonalen Komponente:
# Die saisonale Komponente beschreibt wiederkehrende Muster innerhalb eines festen Zeitintervalls (z. B. monatliche oder jährliche Zyklen). Die Schritte zur Bestimmung der saisonalen Komponente sind:
#
#     Saisonmittelwerte: Für jeden saisonalen Abschnitt (z. B. jeden Monat) wird der durchschnittliche Wert über mehrere Jahre hinweg berechnet, um die typische saisonale Schwankung zu erfassen.
#     Saisonbereinigung: Nachdem der Trend aus den Daten entfernt wurde, kann die verbleibende saisonale Komponente durch den Vergleich von Datenpunkten desselben Zeitabschnitts (z. B. jedes Januar-Datum) geschätzt werden.
#     Beispiel: In den monatlichen Verkaufszahlen eines Einzelhandelsunternehmens könnten die Dezember-Umsätze aufgrund der Weihnachtssaison immer deutlich höher sein.
#
# 4. Bestimmung der zyklischen Komponente (falls vorhanden):
# Die zyklische Komponente umfasst langfristige Schwankungen, die nicht an feste Zeitintervalle gebunden sind, sondern durch makroökonomische Faktoren oder andere systemische Einflüsse verursacht werden.
#
#     Zyklische Komponenten sind oft schwerer zu isolieren und werden durch längere Zeiträume und fortgeschrittenere statistische Modelle (z. B. ARIMA) identifiziert.
#     Es kann auch sinnvoll sein, den Trend und die saisonalen Komponenten zuerst zu entfernen, bevor man nach zyklischen Mustern sucht.
#     Beispiel: Ein Konjunkturzyklus in einer Wirtschaft könnte eine zyklische Schwankung in den Umsätzen eines Unternehmens verursachen.
#
# 5. Berechnung der Restkomponente (Fehlerterm):
# Sobald die Trend-, saisonale und zyklische Komponente entfernt wurden, bleibt der Rest (oder Fehlerterm). Dieser Teil der Zeitreihe enthält zufällige Schwankungen, die durch unvorhersehbare Ereignisse verursacht werden.
#
#     Die Restkomponente sollte keiner erkennbaren Struktur folgen und möglichst wie „weißes Rauschen“ erscheinen – d. h. keine Korrelation zwischen den einzelnen Restwerten.
# 6. Zusammenführung der Komponenten:
# Nach der Zerlegung kann die Zeitreihe in ihre Bestandteile zerlegt und separat analysiert werden.
# ### d) Merkmale einer Zeitreihe
# Eine Zeitreihe wird in der Regel durch zwei wesentliche Merkmale charakterisiert:
#
# 1. Zeitindex (t):
# - Beschreibung: Der Zeitindex gibt die Zeitpunkte an, zu denen die Beobachtungen in der Zeitreihe aufgezeichnet werden. Diese Zeitpunkte müssen in geordneter Reihenfolge vorliegen und oft in gleichmäßigen Abständen (z. B. täglich, wöchentlich, monatlich, jährlich), aber sie können auch unregelmäßig sein.
# - Form: Das kann ein diskreter Zeitindex sein (wie z. B. 1, 2, 3 für die ersten drei Monate) oder tatsächliche Zeitpunkte (z. B. 01.01.2020, 01.02.2020, 01.03.2020). Der Zeitindex dient dazu, die Datenpunkte zu verankern und in ihrer zeitlichen Reihenfolge zu halten.
# - Beispiel: Für eine Zeitreihe monatlicher Verkaufszahlen eines Unternehmens könnte der Zeitindex 𝑡 die Monate Januar, Februar, März usw. darstellen.
#
# 2. Werte (Y(t))
# - Beschreibung: Der Wert der Zeitreihe. Y(t) ist der gemessene Datenpunkt zum Zeitpunkt 𝑡. Das ist die Beobachtung, die zu jedem Zeitpunkt in der Zeitreihe gesammelt wird. Es kann sich dabei um beliebige numerische oder kategorische Werte handeln, die das interessierende Phänomen zu einem bestimmten Zeitpunkt beschreiben (z. B. Temperatur, Aktienkurs, Verkaufszahlen).
# - Form: Die Werte können kontinuierlich oder diskret sein und je nach Anwendung verschiedene Einheiten haben.
# - Beispiel: In der Zeitreihe der monatlichen Verkaufszahlen wäre der Wert Y(t) die Verkaufszahl des Unternehmens im jeweiligen Monat.
# ### e) Arten von Zeitreihen
# Es gibt verschiedene Arten von Zeitreihen, die sich aufgrund ihrer Struktur, ihrer Eigenschaften und ihres Verhaltens über die Zeit hinweg unterscheiden. Diese Klassifikationen helfen dabei, die richtige Analysemethode oder das geeignete Modell auszuwählen. Im Folgenden werde ich die wichtigsten Arten von Zeitreihen vorstellen und erklären, wie sie sich unterscheiden.
#
# 1. Stationäre vs. Nicht-stationäre Zeitreihen
#
#     1.1 Stationäre Zeitreihen
#     Definition: Eine Zeitreihe ist stationär, wenn ihre statistischen Eigenschaften (z. B. Mittelwert, Varianz, Autokorrelation) über die Zeit konstant bleiben. Dies bedeutet, dass die Zeitreihe keinen langfristigen Trend aufweist und ihre Schwankungen um einen konstanten Mittelwert erfolgen.
#
#     Merkmale:
#     - Der Mittelwert ist konstant über die Zeit.
#     - Die Varianz ist konstant (kein zunehmendes oder abnehmendes Rauschen).
#     - Keine langfristigen Trends oder saisonalen Muster.
#     - Autokorrelation hängt nur vom Zeitabstand ab und nicht von der absoluten Zeit.
#     Beispiel: Eine Serie von täglichen Temperaturschwankungen, die über mehrere Jahre hinweg keinen langfristigen Trend aufweist, sondern um einen festen Mittelwert schwankt.
#
#     Unterscheidung: Du kannst eine Zeitreihe auf Stationarität testen, z. B. mit dem Dickey-Fuller-Test (ADF-Test). Eine Zeitreihe ist stationär, wenn der Test statistisch signifikant ist (d.h. die Nullhypothese der Nicht-Stationarität wird abgelehnt).
#
#     1.2 Nicht-stationäre Zeitreihen
#     Definition: Eine Zeitreihe ist nicht-stationär, wenn sich ihre statistischen Eigenschaften über die Zeit ändern. Typischerweise weisen nicht-stationäre Zeitreihen einen Trend, eine Saisonalität oder eine veränderliche Varianz auf.
#
#     Merkmale:
#     - Der Mittelwert ändert sich über die Zeit (z. B. ein auf- oder absteigender Trend).
#     - Die Varianz kann zunehmen oder abnehmen.
#     - Saisonale Muster, die sich regelmäßig wiederholen.
#     Beispiel: Aktienkurse, die langfristig steigen, aber auch saisonale Schwankungen und kurzfristige Volatilität aufweisen.
#
#     Unterscheidung: Ein ADF-Test zeigt an, dass die Zeitreihe nicht stationär ist, wenn die Nullhypothese nicht abgelehnt wird. Solche Zeitreihen erfordern möglicherweise Transformationen (z. B. Differenzierung), um stationär gemacht zu werden.
#
# 2. Deterministische vs. Stochastische Zeitreihen
#
#     2.1 Deterministische Zeitreihen
#     Definition: Eine deterministische Zeitreihe folgt einem festen mathematischen Gesetz oder Modell, und die Werte der Zeitreihe sind vorhersagbar, wenn das Modell bekannt ist.
#
#     Merkmale:
#     - Es gibt keine zufälligen oder stochastischen Elemente.
#     - Das Verhalten der Zeitreihe kann vollständig durch ein mathematisches Modell beschrieben werden.
#     Beispiel: Eine sinusförmige Zeitreihe, die einem klar definierten mathematischen Modell (z. B. y(t)=Asin(Bt)) folgt.
#
#     Unterscheidung: Deterministische Zeitreihen haben keine zufälligen Schwankungen oder Rauschen. Sie folgen einem klaren, vordefinierten Muster.
#
#     2.2 Stochastische Zeitreihen
#     Definition: Eine stochastische Zeitreihe enthält zufällige Elemente, und die Werte der Zeitreihe können nicht vollständig vorhergesagt werden, auch wenn das zugrunde liegende Modell bekannt ist.
#
#     Merkmale:
#     - Enthält eine zufällige Komponente oder Rauschen.
#     - Das Verhalten der Zeitreihe kann nur probabilistisch beschrieben werden.
#     Beispiel: Aktienkurse oder Wetterdaten, die zufälligen Schwankungen unterliegen.
#
#     Unterscheidung: Stochastische Zeitreihen enthalten Zufallselemente, die dazu führen, dass die Werte nicht vollständig vorhersagbar sind, auch wenn sie einem stochastischen Modell folgen.
#
# 3. Univariate vs. Multivariate Zeitreihen
#
#     3.1 Univariate Zeitreihen
#     Definition: Eine univariate Zeitreihe enthält nur eine Variable, die über die Zeit hinweg beobachtet wird.
#
#     Merkmale:
#     - Nur ein einzelner Messwert wird zu jedem Zeitpunkt erfasst.
#     Beispiel: Die täglichen Temperaturen in einer Stadt, die Aktienpreise eines Unternehmens oder die monatlichen Verkaufszahlen eines Produkts.
#
#     Unterscheidung: Univariate Zeitreihen enthalten nur eine einzige Dimension von Daten, die analysiert werden müssen.
#
#     3.2 Multivariate Zeitreihen
#     Definition: Eine multivariate Zeitreihe enthält mehrere Variablen, die über die Zeit hinweg beobachtet werden, wobei diese Variablen möglicherweise miteinander in Beziehung stehen.
#
#     Merkmale:
#     - Mehrere Messwerte werden gleichzeitig erfasst.
#     - Die Variablen können miteinander korrelieren.
#     Beispiel: Das tägliche Wetter mit Variablen wie Temperatur, Luftfeuchtigkeit und Luftdruck, oder die Umsatzdaten eines Unternehmens mit mehreren Produkten über die Zeit.
#
#     Unterscheidung: Multivariate Zeitreihen enthalten mehrere Variablen, die gleichzeitig analysiert werden müssen, oft unter Berücksichtigung von Abhängigkeiten zwischen den Variablen.
#
# 4. Saisonale vs. Nicht-saisonale Zeitreihen
#
#     4.1 Saisonale Zeitreihen
#     Definition: Eine saisonale Zeitreihe weist regelmäßige Muster auf, die sich in gleichen Zeitabständen wiederholen, wie z. B. tägliche, monatliche oder jährliche Muster.
#
#     Merkmale:
#     - Die Daten weisen regelmäßige, wiederkehrende Muster auf, die oft durch externe Faktoren wie Jahreszeiten, Geschäftszyklen oder soziale Faktoren verursacht werden.
#     - Saisonalität kann additiv (gleiche Amplitude über die Zeit) oder multiplikativ (Amplitude wächst oder schrumpft im Verhältnis zum Trend) sein.
#     Beispiel: Einzelhandelsumsätze, die jedes Jahr vor Weihnachten ansteigen, oder monatliche Energienachfrage, die im Winter höher ist.
#
#     Unterscheidung: Saisonale Zeitreihen haben deutlich erkennbare Muster, die sich regelmäßig über die Zeit wiederholen. Diese können durch periodische Ereignisse erklärt werden.
#
#     4.2 Nicht-saisonale Zeitreihen
#     Definition: Eine nicht-saisonale Zeitreihe hat keine regelmäßigen, wiederkehrenden Muster.
#
#     Merkmale:
#     - Keine regelmäßigen Muster in festen Abständen.
#     - Schwankungen sind möglicherweise zufällig oder auf andere nicht-periodische Faktoren zurückzuführen.
#     Beispiel: Zufällige Bewegungen von Aktienkursen, die keine regelmäßige Saisonalität aufweisen.
#
#     Unterscheidung: Nicht-saisonale Zeitreihen haben keine regelmäßigen, wiederkehrenden Muster, die sich über gleiche Zeiträume hinweg wiederholen.
#
# 5. Trendbehaftete vs. Trendlose Zeitreihen
#
#     5.1 Trendbehaftete Zeitreihen
#     Definition: Eine trendbehaftete Zeitreihe zeigt über die Zeit einen klaren auf- oder absteigenden Verlauf, der eine langfristige Tendenz in den Daten widerspiegelt.
#
#     Merkmale:
#     - Es gibt eine langfristige Tendenz in den Daten (steigend oder fallend).
#     - Der Trend kann linear oder nicht-linear (z. B. exponentiell) sein.
#     Beispiel: Wirtschaftswachstum oder der langfristige Anstieg der globalen Temperaturen.
#
#     Unterscheidung: Zeitreihen mit einem klaren Trend, der über längere Zeiträume hinweg sichtbar ist, wie z. B. der Anstieg von Aktienkursen oder das Bevölkerungswachstum.
#
#     5.2 Trendlose Zeitreihen
#     Definition: Eine trendlose Zeitreihe weist keinen langfristigen Trend auf und schwankt um einen konstanten Mittelwert.
#
#     Merkmale:
#     - Es gibt keine klare, langfristige auf- oder absteigende Tendenz.
#     - Die Daten variieren um einen festen Mittelwert ohne langfristige Verschiebungen.
#     Beispiel: Schwankungen von Wetterdaten um einen konstanten Mittelwert über mehrere Jahre hinweg.
#
#     Unterscheidung: Zeitreihen, die keinen sichtbaren langfristigen Trend zeigen, sondern sich um einen konstanten Wert bewegen.
