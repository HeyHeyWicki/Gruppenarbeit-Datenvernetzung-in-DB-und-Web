# %% [markdown]
# ### Aufgabe 3

# %% [markdown]
# a)  Die in Aufgabe 2 generierten Daten sollen mit Hilfe der Methode «pd.read_csv()» aus dem Modul/Bibliothek «pandas», eingelesen werden.
#
# b)  Füge nun den Daten eine Spaltenüberschrift «ZufallsZahl» hinzu und gib die ersten sechs Zeilen der Daten aus.
#
# c)  Da die Daten mit Hilfe der «pandas»-Methode «read_csv()» eingelesen worden sind, gibt es nun eine Möglichkeit, sich schnell einen Überblick über die Daten zu beschaffen. Der Befehl heisst «describe». Lass dir dadurch die wichtigsten Parameter anzeigen. Welche Bedeutung haben die einzelnen Parameter?
#
# d)  Erstelle mit Hilfe der Pandas-Methode ein Histogramm. Die Anzahl der Klassen 𝑘 wird in der Regel durch die Formel 𝑘 = ⌊√𝑛⌋ festgelegt.

# %%
import pandas as pd

# a) Einlesen der Daten mit zwei wichtigen Parametern: 
# 1) decimal legt fest, wie das Dezimalkomma definiert ist
# 2) header legt fest, ob in den Daten eine Spaltenbeschriftung existiert oder nicht
daten = pd.read_csv('Daten/daten_p3_2.txt', decimal ='.', header = None)

# b) wir können eine Spaltenüberschrift hinzufügen
daten.columns = ['ZufallsZahl']
daten.index.name = 'Wurf'
daten.index = daten.index + 1

# und nur gerade die ersten 5 Zeilen ausgeben
print("b)", daten.head(6))

# c) gib die deskriptiven Masse aus:
print("c)", daten.describe())

# d) Histogramm der Zufallszahlen erstellen
daten.hist()
# Out:
# b)       ZufallsZahl
# Wurf
# 1       17.243754
# 2       21.202999
# 3       18.009871
# 4       19.893662
# 5       17.221681
# 6       17.375744
# c)        ZufallsZahl
# count  1000.000000
# mean     17.605391
# std       1.805944
# min      10.807563
# 25%      16.405003
# 50%      17.584068
# 75%      18.859344
# max      24.281484
# array([[<Axes: title={'center': 'ZufallsZahl'}>]], dtype=object)
