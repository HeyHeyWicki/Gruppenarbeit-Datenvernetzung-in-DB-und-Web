# %% [markdown]
# Kapitel 1: "Hello, World!"

# %%
# Ausgabe ohne Print
name='Wicki Mario'
'Hallo ' + name + '!'
# Out:
# 'Hallo Wicki Mario!'

# %%
# Ausgabe mit Print
name='Wicki Mario'
print('Hallo ' + name + '!')
# Out:
# Hallo Wicki Mario!

# %%
# Rechnen mit dem Operator
2**5
# Out:
# 32

# %%
# Rechnen mit dem Operator
2**100
# Out:
# 1267650600228229401496703205376

# %%
# Rechnen mit dem Operator
2**1000
# Out:
# 

# %%
# Zeichenketten
s='lernen Sie Python kennen!'
len(s)              # Länge der Zeichenkette ermitteln
# Out:
# 25

# %%
# Zeichenketten
s='lernen Sie Python kennen!'
s.upper()           # in Grossbuchstaben umwandeln
# Out:
# 'LERNEN SIE PYTHON KENNEN!'

# %%
# Zeichenketten
s='lernen Sie Python kennen!'
s.lower()           # in Kleinbuchstaben umwandeln
# Out:
# 'lernen sie python kennen!'

# %%
# Zeichenketten
s='lernen Sie Python kennen!'
s.find('Python')    # suchen und...
# Out:
# 11

# %%
# Zeichenketten
s='lernen Sie Python kennen!'
s.replace('e','x')  # ersetzen
# Out:
# 'lxrnxn Six Python kxnnxn!'

# %%
# Zeichenketten
s='lernen Sie Python kennen!'
s[5:10]             # Zeichenketten ausschneiden
# Out:
# 'n Sie'

# %%
# Listen, Tupel, Sets und Dictionaries
lst = [1, 2, 4, 8, 16]              # eine fünfteilige Liste

# %%
lst = [1, 2, 4, 8, 16]
lst[2]                              # das dritte Element
                                    # (die Zählung beginnt mit 0)
# Out:
# 4

# %%
lst = [1, 2, 4, 8, 16]
lst.extend([32])                    # Element am Ende hinzufügen
lst
# Out:
# [1, 2, 4, 8, 16, 32]

# %%
lst = [1, 2, 4, 8, 16, 32]
list(map(lambda x: x*2 + 1, lst))   # die Formel x -> x*2+1 auf
                                    # alle Elemente anwenden
# Out:
# [3, 5, 9, 17, 33, 65]

# %%
# for-Schleifen
for i in range(4):
    print(i)
# Out:
# 0
# 1
# 2
# 3

# %%
# Beispieldatei HelloName.Py
import time, locale
name = input('Geben Sie Ihren Namen an: ')
print('Hallo %s!' % name)

# Datum und Zeit in schweizer Lokalisierung
locale.setlocale(locale.LC_ALL, 'de_DE')    # Linux, macOS
locale.setlocale(locale.LC_ALL, 'german')   # Windows
time = time.strftime('Heute ist %A, der %d. %B.')
print (time)
# Out:
# Hallo Mario Wicki!
# Heute ist Montag, der 25. November.
